# %% [markdown]
# # Live Predictions

# %% [markdown]
# Here you can upload any test image and use the fine-tuned YOLOv8 in the main notebook.
#
# Run these cells and change the image path to one that you upload to the notebook.
#
# \
#
# ---

# %%
# !pip install ultralyticsplus

# %%
from ultralyticsplus import YOLO, render_result

# load best model weights 'best.pt' @ Hugging Face
model = YOLO('flkennedy/YOLOv8s-building-segmentation-demo')

# set image path here, jpeg format definitely works.
# upload using the 'Files' area on the left bar of the notebook
image = 'YOUR-IMAGE-FILENAME.jpeg'

# prediction on your image
results = model.predict(image)

render = render_result(model=model, image=image, result=results[0])
render
# Out:
# Ultralytics YOLOv8.0.43 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU
# YOLOv8s-seg summary (fused): 195 layers, 11779987 parameters, 0 gradients, 42.4 GFLOPs
#
# image 1/1 /content/image_1.jpeg: 416x640 29 Buildings, 1322.4ms
# Speed: 3.3ms preprocess, 1322.4ms inference, 88.1ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=960x600>
